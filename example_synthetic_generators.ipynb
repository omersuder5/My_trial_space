# %%
import numpy as np
import torch 
import matplotlib.pyplot as plt

import utils.data
from generators.synthetic_generators import *

# %load_ext autoreload
# %autoreload 2

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
dtype=torch.float64

# %% [markdown]
# # AR

# %%
T = 200 # length of time series
N = 50  # number of samples
d = 1   # dimension of time series
p = 2   # AR order
q = 0   # MA order
phi = [0.7, -0.2] # AR coefficients
theta = None # MA coefficients

x_ar = ARMA(T=T, p=p, q=q, phi=phi, theta=theta)

# %% [markdown]
# ### normal noise

# %%
x_ar_samples = x_ar.generate(N=N, noise=Noise("normal")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_ar_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 AR Samples with Normal Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ### t noise

# %%
x_ar_samples = x_ar.generate(N=N, noise=Noise("t")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_ar_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 AR Samples with t-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ### gamma noise

# %%
x_ar_samples = x_ar.generate(N=N, noise=Noise("gamma")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_ar_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 AR Samples with Gamma-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # MA

# %%
q = 2  # MA order
p = 0  # AR order
theta = [0.5, 0.3]  # MA coefficients
phi = None  # AR coefficients

x_ma = ARMA(T=T, p=p, q=q, phi=phi, theta=theta)

# %%
x_ma_samples = x_ma.generate(N=N, noise=Noise("normal")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_ma_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 MA Samples with Normal Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x_ma_samples = x_ma.generate(N=N, noise=Noise("t")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_ma_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 MA Samples with t-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x_ma_samples = x_ma.generate(N=N, noise=Noise("gamma")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_ma_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 MA Samples with Gamma-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # ARMA

# %%
p = 2  # AR order
q = 2  # MA order
phi = [0.7, -0.2]  # AR coefficients
theta = [0.5, 0.3]  # MA coefficients

x_arma = ARMA(T=T, p=p, q=q, phi=phi, theta=theta)

# %%
x_arma_samples = x_arma.generate(N=N, noise=Noise("normal")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_arma_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 ARMA Samples with Normal Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x_arma_samples = x_arma.generate(N=N, noise=Noise("t")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_arma_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 ARMA Samples with t-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x_arma_samples = x_arma.generate(N=N, noise=Noise("gamma")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_arma_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 ARMA Samples with Gamma-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # GARCH

# %%
# GARCH parameters
omega = 0.1
alpha = [0.1]
beta = [0.85]
sigma2_0 = 0.2

x_garch = GARCH11(T=T, omega=omega, alpha=alpha[0], beta=beta[0], d=d, sigma2_0=sigma2_0)

# %%
x_garch_samples = x_garch.generate(N=N, noise=Noise("normal")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_garch_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 GARCH Samples with Normal Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x_garch_samples = x_garch.generate(N=N, noise=Noise("t")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_garch_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 GARCH Samples with t-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x_garch_samples = x_garch.generate(N=N, noise=Noise("gamma")).to(device=device, dtype=dtype)

plt.figure(figsize=(10, 3))
for idx in range(5):
    plt.plot(x_garch_samples[idx].squeeze().numpy(), label=f'Sample {idx+1}')
plt.title('First 5 GARCH Samples with Gamma-Distributed Noise')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()
